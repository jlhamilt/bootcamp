# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

import bokeh.io
import bokeh.plotting
import bokeh.mpl

# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}
bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7b2a4ce8-6f96-4cfd-9ed8-b5d50bfb99bb">Loading BokehJS ...</span>
#     </div>

# %%
print('Hello, world.')
# Out:
# Hello, world.

# %% [markdown]
# I can type text too!

# %% [markdown]
# I can also *also* make italics on words. Or I can **boldly** go.

# %% [markdown]
# This year's bootcamp class is:
# - Hard-working.
#     - 9am - 10pm for heaven's sake
# - Kind.
# - Good looking.
# - Tired
#
# Treat this equation as latex:
# $m = m_0 e^{rt}$
#
# Even cooler:
# \begin{align}
# \frac{\mathrm{d}m}{\mathrm{d}t} &= rt \\
# m &= m_0 e^{rt}
# \end{align}

# %% [markdown]
# $n\left(n - \frac{1}{2}\right)$

# %%
df = pd.read_csv('data/grant_1987.csv', comment='#')

# %%
df
# Out:
#       band   species  Beak length, mm  Beak depth, mm
# 0    14613    fortis             9.10            7.00
# 1    15487    fortis             9.14            7.12
# 2    15187    fortis             9.24            7.21
# 3    15284    fortis             9.20            7.30
# 4    14983    fortis             8.83            7.32
# 5    14913    fortis             9.14            7.41
# 6    15726    fortis             9.04            7.42
# 7    15821    fortis            10.56            7.43
# 8    15484    fortis             9.70            7.45
# 9     4968    fortis             9.25            7.50
# 10   15695    fortis             9.50            7.50
# 11   15272    fortis             9.34            7.51
# 12   15256    fortis             9.64            7.51
# 13   13907    fortis             9.04            7.64
# 14    5578    fortis             9.80            7.65
# 15   10376    fortis             9.28            7.68
# ...

# %%
bl_fortis = df.loc[df['species']=='fortis', 'Beak length, mm']
bd_fortis = df.loc[df['species']=='fortis', 'Beak depth, mm']
bl_scandens = df.loc[df['species']=='scandens', 'Beak length, mm']
bd_scandens = df.loc[df['species']=='scandens', 'Beak depth, mm']

plt.plot(bl_fortis, bd_fortis, '.')
plt.plot(bl_scandens, bd_scandens, '.')

# Make it interactive with Bokeh
bokeh.plotting.show(bokeh.mpl.to_bokeh())
# This is just a hack to try converting matplotlib stuff to bokeh.
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="560993e1-984a-4c9b-b969-eab8d7c54aef"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
p = bokeh.plotting.figure(height=400, width=500, x_axis_label='beak length (mm)', y_axis_label='beak depth (mm)')
p.circle(bl_fortis, bd_fortis, color='dodgerblue', alpha=0.5, legend='Fortis')
p.circle(bl_scandens, bd_scandens, color='tomato', alpha=0.5, legend='Scandens')

bokeh.plotting.show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="b7bb89cf-5074-4bba-8174-3a73c5529aa5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...
